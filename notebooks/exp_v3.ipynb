# %%
import pandas as pd

# The path to your CSV file
file_path = "../evaluation_data/documents.xlsx"

# %%
try:
    # Read the file into a DataFrame
    # Most common alternative for non-UTF-8 files
    df = pd.read_excel(file_path, names=["name", "content"], header=None)

    print("✅ Successfully connected to and read the CSV file.")
    print("\n--- First 5 Rows ---")
    print(df.head())
    print("\n--- Data Structure ---")
    print(df.info())

except FileNotFoundError:
    print(f"❌ Error: The file at '{file_path}' was not found.")
except pd.errors.EmptyDataError:
    print("❌ Error: The file is empty.")
# Out:
# ✅ Successfully connected to and read the CSV file.
#
# --- First 5 Rows ---
#      name                                            content
# 0  Test_A  <START OF DOCUMENT: Test_A.docx AltName:Source...
# 1  Test_C  <START OF DOCUMENT: Test_C.docx AltName:Source...
# 2  Test_D  <START OF DOCUMENT: Test_D.docx AltName:Source...
# 3  Test_F  <START OF DOCUMENT: Test_F.docx AltName:Source...
#
# --- Data Structure ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   content  4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes
# None

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.path.dirname("scripts"), "..")))

from scripts.preprocess import clean_document_for_llm


clean_document_for_llm(df["content"].iloc[0])
# Out:
# '\\nBUSINESS PARTNERSHIP AGREEMENT BETWEEN Orval O\'Riocht of 15 Grafton Street, Dublin 2, Ireland, PPS Number: 8472639T, Phone: +353\\-1\\-485\\-2739, Email: orval.oriocht@rightbrothers.ie, Irish Passport Number: P8472639 AND Liam O\'Riocht of 42 Merrion Square, Dublin 2, Ireland, PPS Number: 6159287K, Phone: +353\\-1\\-673\\-4821, Email: liam.oriocht@rightbrothers.ie, Irish Passport Number: P6159287 (hereinafter individually referred to as a \\"Partner\\" and collectively as the \\"Partners\\").\\n\\nThis Business Partnership Agreement (the \\"Agreement\\") is made on July 17, 2025, between the Partners, both residents of Ireland, who agree to form a partnership under the name \\"The Right Brothers\\" (the \\"Partnership\\") for selling used airplane parts, subject to the following terms:\\n\\n1. FORMATION\\n\\nThe Partners form a general partnership under Irish law named \\"The Right Brothers\\" with principal place of business at Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland, Phone: +353-1-842-5731, Email: info@rightbrothers.ie, VAT Number: IE8472639T.\\n\\n2. PURPOSE\\n\\nThe Partnership will source, refurbish, market, and sell used airplane parts and engage in related activities as agreed by the Partners.\\n\\n3. CAPITAL CONTRIBUTIONS\\n\\nInitial capital of €50,000 contributed as follows: Orval O\'Riocht: €30,000 (60%), Liam O\'Riocht: €20,000 (40%). Additional contributions may be required by unanimous agreement.\\n\\n4. PARTNERSHIP INTERESTS AND PROFIT AND LOSS ALLOCATION\\n\\nPartnership interests: Orval O\'Riocht: 60%, Liam O\'Riocht: 40%. Profits and losses allocated proportionally.\\n\\n5. MANAGEMENT AND OPERATION\\n\\nBoth Partners have equal management rights. Major decisions require unanimous agreement including: admitting new partners, selling substantially all assets, incurring debt over €10,000, and changing business nature. Partnership funds deposited at Bank of Ireland, Account Number: IE64 BOFI 9073 2847 6391 52, Sort Code: 90-73-28. Both Partners\' signatures required for withdrawals over €2,500.\\n\\n7. SALARIES AND DRAWINGS\\n\\nEach Partner receives €3,000 monthly drawing against profit share.\\n\\n8. DUTIES AND RESPONSIBILITIES\\n\\nOrval O\'Riocht (Driver\'s License: 8472639, Aircraft Maintenance License: AML-IE-8472639) handles marketing, sales, and financial management.Liam O\'Riocht (Driver\'s License: 6159287, Chartered Accountant License: CA-IE-6159287) handles sourcing, quality control, and inventory.\\n\\nNo Partner may transfer their interest without first offering to the other Partner, who has 30 days to accept. Value determined by mutual agreement or independent appraisal. Upon death, disability, or retirement, the surviving Partner may purchase the other\'s interest at fair market value. If not exercised, the Partnership dissolves. Partnership dissolves upon Partners\' agreement, death, retirement, or disability. Upon dissolution, assets pay creditors first, then return capital contributions, then distribute remaining funds per ownership percentages. Disputes resolved through good faith discussion, then mediation, then arbitration under Chartered Institute of Arbitrators, Irish Branch rules in Dublin, Ireland. This Agreement constitutes the entire agreement, may only be modified in writing, and is governed by Irish law.\\n\\nIN WITNESS WHEREOF, the Partners have executed this Agreement as of the date first above written.WITNESSED BY: Michael Murphy, Address: 28 Fitzwilliam Square, Dublin 2, Ireland, Phone: +353-1-291-8463; Sean O\'Malley, Address: 17 Stephen\'s Green, Dublin 2, Ireland, Phone: +353-1-537-9284\\n\\nTax Information: Partnership Tax Reference: 8472639T\\-6159287K, Revenue Registration: RC\\-RB\\-2025\\-847263, Employer Registration: ER\\-8472639\\-6159287\\n\\n'

# %%
from scripts.preprocess import clean_document_for_llm
for i in range(df.shape[0]):
    raw_text = df["content"].iloc[i]
    clean_text =clean_document_for_llm(raw_text)
    print(f"✅ {i} text length: {len(clean_text)}")

# clean_text = print(clean_document_for_llm(raw_text))
# Out:
# ✅ 0 text length: 3311
# ✅ 1 text length: 1666
# ✅ 2 text length: 2053

# %%
from scripts.read_file import parse_label_document, parse_document_to_json

file_path = "evaluation_data/labels.txt"

# %%
try:
    with open(file_path, "r", encoding="utf-8") as file:
        # The 'r' mode stands for read mode
        # The 'encoding' is vital to prevent UnicodeDecodeError (UTF-8 is standard)

        # Read the entire content of the file into the 'content' variable
        raw_labels = file.read()

    print("✅ File successfully read.")
    print("\n--- File Content Snippet ---")
    print(raw_labels[:500] + "...")  # Print first 500 characters

except FileNotFoundError:
    print(f"❌ Error: The file at '{file_path}' was not found.")
except UnicodeDecodeError:
    print(
        "❌ Error: Could not decode using 'utf-8'. Try specifying a different encoding (e.g., 'latin-1')."
    )
# Out:
# ✅ File successfully read.
#
# --- File Content Snippet ---
# Test A
#
# ###Name #Orval O'Riocht
# ###Name #Liam O'Riocht
# ###Name #Michael Murphy
# ###Name #Sean O'Malley
# ###Company_Name #The Right Brothers
# ###Company_Name #Bank of Ireland
# ###Address #15 Grafton Street, Dublin 2, Ireland
# ###Address #42 Merrion Square, Dublin 2, Ireland
# ###Address #28 Fitzwilliam Square, Dublin 2, Ireland
# ###Address #17 Stephen's Green, Dublin 2, Ireland
# ###Address #Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland
# ###PPS_Number #8472639T
# ###PPS_Number #6159287K
# ###L...

# %%
structured_dict = parse_document_to_json(raw_labels)

# Final step: Convert the Python dictionary into a formatted JSON string
json_output = json.dumps(structured_dict, indent=4)

print("\n--- Parsed and Structured JSON Output Snippet ---")
print(json_output[:1000] + "...")
# Out:
# --- Parsed and Structured JSON Output Snippet ---
# {
#     "Test A": {
#         "Name": [
#             "Orval O'Riocht",
#             "Liam O'Riocht",
#             "Michael Murphy",
#             "Sean O'Malley"
#         ],
#         "Company_Name": [
#             "The Right Brothers",
#             "Bank of Ireland"
#         ],
#         "Address": [
#             "15 Grafton Street, Dublin 2, Ireland",
#             "42 Merrion Square, Dublin 2, Ireland",
#             "28 Fitzwilliam Square, Dublin 2, Ireland",
#             "17 Stephen's Green, Dublin 2, Ireland",
#             "Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland"
#         ],
#         "PPS_Number": [
#             "8472639T",
#             "6159287K"
#         ],
#         "License_Number": [
#             "8472639",
#             "AML-IE-8472639",
#             "6159287",
#             "CA-IE-6159287"
#         ],
#         "Phone_Number": [
#             "+353-1-485-2739",
#             "+353-1-842-5731",
#             "+353-1-673-4821",
#             "+353-1-291-8463",
#             "+353-1-537-9284"
#        ...

# %%
import json

output_file_path = "parsed_data.json"

try:
    # Open the file in write mode ('w')
    with open(output_file_path, "w", encoding="utf-8") as f:
        # Use json.dump() to write the dictionary to the file stream.
        # indent=4 makes the JSON human-readable with 4-space indentation.
        json.dump(structured_dict, f, indent=4, ensure_ascii=False)

    print(f"✅ Successfully saved structured data to: **{output_file_path}**")

except Exception as e:
    print(f"❌ Error occurred while saving the file: {e}")
# Out:
# ✅ Successfully saved structured data to: **parsed_data.json**
