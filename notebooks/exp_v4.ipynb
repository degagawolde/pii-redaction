# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.path.dirname("scripts"), "..")))

from scripts.evaluation import (
    calculate_pii_metrics,
    print_metrics_report,
)

# %%
# --- Example Usage (Using your provided inputs) ---

predictions = {
    "Test_A": {
            "Name": [
                "Orval O'Riocht",
                "Liam O'Riocht",
                "Michael Murphy",
                "Sean O'Malley",
            ],
            "Company_Name": [
                "rightbrothers.ie",
                "The Right Brothers",
                "Bank of Ireland",
            ],
            "Address": [
                "15 Grafton Street, Dublin 2, Ireland",
                "42 Merrion Square, Dublin 2, Ireland",
                "Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland",
                "28 Fitzwilliam Square, Dublin 2, Ireland",
                "17 Stephen's Green, Dublin 2, Ireland",
            ],
            "Date_of_Birth": [],
            "Email_Address": [
                "orval.oriocht@rightbrothers.ie",
                "liam.oriocht@rightbrothers.ie",
                "info@rightbrothers.ie",
            ],
            "Phone_Number": [
                "+353-1-485-2739",
                "+353-1-673-4821",
                "+353-1-842-5731",
                "+353-1-291-8463",
                "+353-1-537-9284",
            ],
            "PPS_Number": ["8472639T", "6159287K"],
            "License_Number": [
                "IE8472639T",
                "8472639",
                "AML-IE-8472639",
                "6159287",
                "CA-IE-6159287",
            ],
            "Passport_Number": ["P8472639", "P6159287"],
            "Bank_Information": ["IE64 BOFI 9073 2847 6391 52", "90-73-28"],
            "ID_Number": [],
            "Reference_Number": [
                "8472639T-6159287K",
                "RC-RB-2025-847263",
                "ER-8472639-6159287",
            ],
    },
    "Test_C": {
            "Name": [
                "Miran Shingali",
                "Grand Duke of Luxembourg",
                "Gianmarco Rossi",
                "President of the Chamber",
                "Agatha Johansson",
                "Judge-Rapporteur",
                "Jakub Dzukowicz",
                "Ms. Elena Sharpova",
                "Elena Sharpova",
                "Mr. Miran Shingali",
                "Ms. Fawziya Shingali (née Taalo)",
                "Fawziya Shingali",
                "Taalo",
                "His Royal Highness Henri",
                "Henri",
                "A. Calot Escobar",
                "Registrar",
            ],
            "Company_Name": [
                "COURT OF JUSTICE OF THE EUROPEAN UNION",
                "Government of Luxembourg",
                "Luxembourg government",
                "Grand Duke's office",
                "THE COURT (Third Chamber)",
                "Registry of the Court of Justice",
            ],
            "Address": [
                "Sinjar, Iraq",
                "Hauptstraße 45, 54290 Trier, Germany",
                "12 Rue de la Liberté, L-1930 Luxembourg City",
                "Palace of the Grand Dukes, 17 Rue du Marché-aux-Herbes, L-1728 Luxembourg City",
                "Rue du Fort Niedergrünewald, L-2925 Luxembourg",
            ],
            "Date_of_Birth": ["23 August 1987", "15 March 1991"],
            "Email_Address": ["registry@curia.europa.eu"],
            "Phone_Number": ["+352 43 03 1"],
            "PPS_Number": [],
            "License_Number": ["DE-2023-RP-445789"],
            "Passport_Number": [],
            "Bank_Information": [],
            "ID_Number": ["19870823-1234-567", "19910315-2345-678"],
            "Reference_Number": [
                "C-247/25",
                "ECLI:EU:C:2025:542",
                "2025/C-247",
                "LU-2014-REF-08947",
                "MS-2025-REV-001",
                "IRQ-2013-MC-78945",
                "MFA-2025-0398",
                "GD-2025-0156",
                "CC-2025-0089",
                "Directive 2011/95/EU",
            ]
    },
    "Test_D": {
            "Name": [
                "Orval O'Riocht",
                "Liam O'Riocht",
                "Michael Murphy",
                "Sean O'Malley",
            ],
            "Company_Name": ["The Right Brothers"],
            "Address": [
                "15 Grafton Street, Dublin 2, Ireland",
                "42 Merrion Square, Dublin 2, Ireland",
                "Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland",
                "28 Fitzwilliam Square, Dublin 2, Ireland",
                "17 Stephen's Green, Dublin 2, Ireland",
            ],
            "Date_of_Birth": [],
            "Email_Address": [
                "orval.oriocht@rightbrothers.ie",
                "liam.oriocht@rightbrothers.ie",
                "info@rightbrothers.ie",
            ],
            "Phone_Number": [
                "+353-1-485-2739",
                "+353-1-673-4821",
                "+353-1-842-5731",
                "+353-1-291-8463",
                "+353-1-537-9284",
            ],
            "PPS_Number": ["8472639T", "6159287K"],
            "License_Number": ["IE8472639T"],
            "Passport_Number": ["P8472639", "P6159287"],
            "Bank_Information": [],
            "ID_Number": [],
            "Reference_Number": [
                "8472639T-6159287K",
                "RC-RB-2025-847263",
                "ER-8472639-6159287",
            ]
    },
    "Test_F": {
            "Name": [
                "Miran Shingali",
                "Gianmarco Rossi",
                "Agatha Johansson",
                "Jakub Dzukowicz",
                "Ms. Elena Sharpova",
                "Elena Sharpova",
                "Mr. Miran Shingali",
                "Ms. Fawziya Shingali",
                "Fawziya Shingali",
                "Henri",
                "His Royal Highness Henri",
                "Grand Duke of Luxembourg",
                "A. Calot Escobar",
            ],
            "Company_Name": [
                "COURT OF JUSTICE OF THE EUROPEAN UNION",
                "Grand Duke of Luxembourg",
                "Government of Luxembourg",
                "Registry of the Court of Justice",
            ],
            "Address": [
                "Hauptstraße 45, 54290 Trier, Germany",
                "12 Rue de la Liberté, L-1930 Luxembourg City",
                "Palace of the Grand Dukes, 17 Rue du Marché-aux-Herbes, L-1728 Luxembourg City",
                "Rue du Fort Niedergrünewald, L-2925 Luxembourg",
            ],
            "Date_of_Birth": ["23 August 1987", "15 March 1991"],
            "Email_Address": ["registry@curia.europa.eu"],
            "Phone_Number": ["+352 43 03 1"],
            "PPS_Number": [],
            "License_Number": ["DE-2023-RP-445789", "IRQ-2013-MC-78945"],
            "Passport_Number": [],
            "Bank_Information": [],
            "ID_Number": ["19870823-1234-567", "19910315-2345-678"],
            "Reference_Number": [
                "C-247/25",
                "2025:542",
                "2025/C-247",
                "LU-2014-REF-08947",
                "MS-2025-REV-001",
                "MFA-2025-0398",
                "GD-2025-0156",
                "CC-2025-0089",
            ],
        
    }
}

ground_truth = {
    "Test_A": {
        "Name": ["Orval O'Riocht", "Liam O'Riocht", "Michael Murphy", "Sean O'Malley"],
        "Company_Name": ["The Right Brothers", "Bank of Ireland"],
        "Address": [
            "15 Grafton Street, Dublin 2, Ireland",
            "42 Merrion Square, Dublin 2, Ireland",
            "28 Fitzwilliam Square, Dublin 2, Ireland",
            "17 Stephen's Green, Dublin 2, Ireland",
            "Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland",
        ],
        "PPS_Number": ["8472639T", "6159287K"],
        "License_Number": ["8472639", "AML-IE-8472639", "6159287", "CA-IE-6159287"],
        "Phone_Number": [
            "+353-1-485-2739",
            "+353-1-842-5731",
            "+353-1-673-4821",
            "+353-1-291-8463",
            "+353-1-537-9284",
        ],
        "Email_Address": [
            "orval.oriocht@rightbrothers.ie",
            "liam.oriocht@rightbrothers.ie",
            "info@rightbrothers.ie",
        ],
        "Passport_Number": ["P6159287", "P8472639"],
        "Bank_Informarion": ["Account Number: IE64 BOFI 9073 2847 6391 52"],
        "Reference_Number": [
            "Sort Code: 90-73-28",
            "8472639T-6159287K",
            "RC-RB-2025-847263",
            "ER-8472639-6159287",
            "IE8472639T",
        ],
    },
    "Test_C": {
        "Name": [
            "Miran Shingali",
            "Fawziya Shingali",
            "Taalo",
            "Mr. Shingali",
            "Gianmarco Rossi",
            "Agatha Johansson",
            "Jakub Dzukowicz",
            "Henri",
            "Elena Sharpova",
            "A. Calot Escobar",
        ],
        "ID_Number": ["19870823-1234-567", "19910315-2345-678"],
        "Date_of_Birth": ["23 August 1987", "15 March 1991"],
        "Address": [
            "Hauptstraße 45, 54290 Trier, Germany",
            "12 Rue de la Liberté, L-1930 Luxembourg City",
            "17 Rue du Marché-aux-Herbes, L-1728 Luxembourg City",
            "Rue du Fort Niedergrünewald, L-2925 Luxembourg",
            "Sinjar, Iraq",
        ],
        "Phone_Number": ["+352 43 03 1"],
        "Email_Address": ["registry@curia.europa.eu"],
        "Reference_Number": [
            "LU-2014-REF-08947",
            "MS-2025-REV-001",
            "DE-2023-RP-445789",
            "IRQ-2013-MC-78945",
            "MFA-2025-0398",
            "GD-2025-0156",
            "CC-2025-0089",
            "C-247/25",
            "2025/C-247",
            "ECLI:EU:C:2025:542",
        ],
    },
    "Test_D": {
        "Name": ["Orval O'Riocht", "Liam O'Riocht", "Michael Murphy", "Sean O'Malley"],
        "Company_Name": ["The Right Brothers", "Bank of Ireland"],
        "Address": [
            "15 Grafton Street, Dublin 2, Ireland",
            "42 Merrion Square, Dublin 2, Ireland",
            "28 Fitzwilliam Square, Dublin 2, Ireland",
            "17 Stephen's Green, Dublin 2, Ireland",
            "Unit 7, Dublin Industrial Estate, Glasnevin, Dublin 11, Ireland",
        ],
        "PPS_Number": ["8472639T", "6159287K"],
        "License_Number": ["8472639", "6159287"],
        "Phone_Number": [
            "+353-1-485-2739",
            "+353-1-842-5731",
            "+353-1-673-4821",
            "+353-1-291-8463",
            "+353-1-537-9284",
        ],
        "Email_Address": [
            "orval.oriocht@rightbrothers.ie",
            "liam.oriocht@rightbrothers.ie",
            "info@rightbrothers.ie",
        ],
        "Passport_Number": ["P6159287", "P8472639"],
        "Bank_Information": ["Account Number: IE64 BOFI 9073 2847 6391 52"],
        "Reference_Number": [
            "Sort Code: 90-73-28",
            "8472639T-6159287K",
            "RC-RB-2025-847263",
            "ER-8472639-6159287",
            "IE8472639T",
        ],
    },
    "Test_F": {
        "Name": [
            "Miran Shingali",
            "Fawziya Shingali",
            "Taalo",
            "Mr. Shingali",
            "Gianmarco Rossi",
            "Agatha Johansson",
            "Jakub Dzukowicz",
            "Henri",
            "Elena Sharpova",
        ],
        "ID_Number": ["19870823-1234-567", "19910315-2345-678"],
        "Date_of_Birth": ["23 August 1987", "15 March 1991"],
        "Address": [
            "Hauptstraße 45, 54290 Trier, Germany",
            "12 Rue de la Liberté, L-1930 Luxembourg City",
            "17 Rue du Marché-aux-Herbes, L-1728 Luxembourg City",
            "Rue du Fort Niedergrünewald, L-2925 Luxembourg",
            "Sinjar, Iraq",
        ],
        "Phone_Number": ["+352 43 03 1"],
        "Email_Address": ["registry@curia.europa.eu"],
        "Reference_Number": [
            "LU-2014-REF-08947",
            "MS-2025-REV-001",
            "DE-2023-RP-445789",
            "IRQ-2013-MC-78945",
            "MFA-2025-0398",
            "GD-2025-0156",
            "CC-2025-0089",
            "C-247/25",
            "2025/C-247",
            "ECLI:EU:C:2025:542",
        ],
    },
}

# %%
# Calculate metrics for Test C
metrics = calculate_pii_metrics(predictions, ground_truth)

# Print comprehensive report
print_metrics_report(metrics)
# Out:
# ...
# PII EXTRACTION EVALUATION REPORT
# ...
#
# OVERALL SUMMARY (Micro/Macro Averages):
# Tests Evaluated: 4
# Categories Found: 13
# Micro Precision: 0.7465
# Micro Recall:    0.8480
# Micro F1-Score:  0.7940
# Macro Precision: 0.7001
# Macro Recall:    0.7607
# Macro F1-Score:  0.7147
#
# PER-CATEGORY METRICS:
# --------------------------------------------------------------------------------
# Category             Precision  Recall     F1-Score   Support    TP/FP/FN
# --------------------------------------------------------------------------------
# Address              0.8947     0.8500     0.8718     20         17/2/3
# Bank_Informarion     0.0000     0.0000     0.0000     1          0/0/1
# Bank_Information     0.0000     0.0000     0.0000     1          0/2/1
# Company_Name         0.2143     0.7500     0.3333     4          3/11/1
# Date_of_Birth        1.0000     1.0000     1.0000     4          4/0/0
# Email_Address        1.0000     1.0000     1.0000     8          8/0/0
# ...
