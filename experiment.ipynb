# %%
from dotenv import load_dotenv
import os
load_dotenv() 

gemini_api_key = os.getenv('GEMINI_API_KEY') 

print(f"The value of GEMINI_API_KEY is: {gemini_api_key}")
# Out:
# The value of GEMINI_API_KEY is: AIzaSyCktOclER5v5Nu8rego7fcOFsanQ5qQpx0

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="AI for developing country",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0),  # Disables thinking
        system_instruction="How does AI work?",
        temperature=0.1,
    ),
)

print(response.text)
# Out:
# That's a fantastic and incredibly important topic! AI for developing countries holds immense potential to accelerate progress, address unique challenges, and improve lives. However, it also comes with its own set of considerations and potential pitfalls.
#
# Let's break down the key aspects of AI for developing countries:
#
# ## The Potential: How AI Can Help
#
# AI can be a powerful tool to leapfrog traditional development stages and address critical issues in developing countries. Here are some key areas:
#
# 1.  **Healthcare:**
#     *   **Diagnosis & Screening:** AI-powered tools can help diagnose diseases like tuberculosis, malaria, and various cancers from medical images (X-rays, scans) even in remote areas with limited specialists.
#     *   **Predictive Analytics:** Forecasting disease outbreaks (e.g., dengue, cholera) based on climate, sanitation, and population data, allowing for proactive interventions.
#     *   **Personalized Medicine:** Tailoring treatments based on individual patient data, especially relevant where generic drug efficacy might vary.
#     *   **Drug Discovery:** Accelerating the development of new drugs for neglected tropical diseases.
#     *   **Telemedicine & Remote Consultation:** AI can assist in triaging cases and providing initial recommendations, making remote healthcare more efficient.
#
# 2.  **Agriculture & Food Security:**
#     *   **Precision Agriculture:** AI can analyze satellite imagery, drone data, and weather patterns to optimize irrigation, fertilization, and pest control, leading to higher yields and reduced waste.
#     *   **Crop Disease Detection:** Early detection of crop diseases through image analysis, preventing widespread losses.
#     *   **Weather Forecasting:** More accurate localized weather predictions to help farmers plan planting and harvesting.
#     *   **Market Access & Price Prediction:** AI can help farmers connect to markets more efficiently and predict price fluctuations, ensuring better income.
#     *   **Livestock Monitoring:** Tracking animal health and productivity.
#
# 3.  **Education:**
#     *   **Personalized Learning:** AI tutors and adaptive learning platforms can tailor educational content to individual student needs and pace, addressing diverse learning levels.
#     *   **Content Localization:** Translating and adapting educational materials into local languages and cultural contexts.
#     *   **Teacher Support:** AI tools can help teachers with grading, lesson planning, and identifying students who need extra help.
#     *   **Access to Knowledge:** AI can summarize complex information, making it more accessible to a wider audience.
#
# 4.  **Financial Inclusion:**
#     *   **Credit Scoring:** AI can analyze alternative data (mobile phone usage, utility payments) to create credit scores for individuals and small businesses without traditional banking history, unlocking access to loans.
#     *   **Fraud Detection:** Protecting vulnerable populations from financial scams.
#     *   **Personalized Financial Advice:** AI chatbots can offer basic financial literacy and advice.
#     *   **Microfinance Optimization:** Improving the efficiency and reach of microfinance institutions.
#
# 5.  **Infrastructure & Urban Planning:**
#     *   **Smart Grids:** Optimizing energy distribution and reducing waste.
#     *   **Traffic Management:** AI can analyze traffic patterns to reduce congestion and improve public transport efficiency.
#     *   **Waste Management:** Optimizing collection routes and identifying recycling opportunities.
#     *   **Disaster Preparedness:** Predicting and mitigating the impact of natural disasters.
#
# 6.  **Governance & Public Services:**
#     *   **Efficient Resource Allocation:** AI can help governments allocate resources more effectively based on data.
#     *   **Corruption Detection:** Identifying patterns indicative of corruption.
#     *   **Improved Public Service Delivery:** Chatbots for citizen inquiries, streamlining bureaucratic processes.
#     *   **Environmental Monitoring:** Tracking deforestation, pollution, and water quality.
#
# ## The Challenges & Considerations:
#
# While the potential is vast, implementing AI in developing countries comes with significant hurdles:
#
# 1.  **Data Scarcity & Quality:**
#     *   **Lack of Data:** Many developing countries lack comprehensive, digitized, and reliable datasets needed to train effective AI models.
#     *   **Bias in Data:** Existing data might reflect historical biases (e.g., gender, ethnicity, socioeconomic status), leading to unfair or inaccurate AI outcomes.
#     *   **Data Privacy & Security:** Protecting sensitive data is crucial, especially with limited regulatory frameworks.
#
# 2.  **Infrastructure & Connectivity:**
#     *   **Limited Internet Access:** Many rural areas lack reliable and affordable internet connectivity, hindering access to cloud-based AI services.
#     *   **Energy Access:** Intermittent or expensive electricity supply can be a major barrier for running AI systems.
#     *   **Hardware Limitations:** Access to powerful computing hardware for training complex AI models can be restricted.
#
# 3.  **Skills Gap & Human Capital:**
#     *   **Lack of AI Expertise:** A shortage of data scientists, AI engineers, and researchers to develop, deploy, and maintain AI solutions.
#     *   **Digital Literacy:** A significant portion of the population may lack the basic digital literacy to interact with AI tools.
#     *   **"Brain Drain":** Talented individuals often seek opportunities in more developed countries.
#
# 4.  **Ethical & Societal Concerns:**
#     *   **Job Displacement:** AI automation could displace jobs in sectors with low-skilled labor, exacerbating unemployment.
#     *   **Bias & Discrimination:** AI models trained on biased data can perpetuate or amplify existing inequalities.
#     *   **Accountability & Transparency:** Who is responsible when an AI system makes a mistake, especially in critical areas like healthcare?
#     *   **Digital Divide:** AI could widen the gap between those with access to technology and those without.
#     *   **Cultural Relevance:** AI solutions must be culturally appropriate and not simply imported from Western contexts.
#
# 5.  **Cost & Sustainability:**
#     *   **High Development Costs:** Developing and deploying AI solutions can be expensive.
#     *   **Maintenance & Updates:** Ongoing costs for maintaining and updating AI systems.
#     *   **Dependency on External Providers:** Reliance on foreign companies for AI technology can create dependency and limit local capacity building.
#
# 6.  **Regulatory & Policy Frameworks:**
#     *   **Lack of AI Governance:** Many developing countries lack comprehensive policies and regulations for AI development and deployment.
#     *   **Intellectual Property:** Challenges in protecting locally developed AI innovations.
#
# ## Strategies for Responsible & Effective AI Development:
#
# To harness AI's potential while mitigating risks, a multi-faceted approach is needed:
#
# 1.  **Focus on "AI for Good" & Local Needs:** Prioritize AI applications that address the most pressing local challenges (e.g., health, food, education) rather than simply adopting trends.
# 2.  **Data Infrastructure & Governance:**
#     *   **Data Collection Initiatives:** Invest in collecting high-quality, representative, and ethical data.
#     *   **Data Sharing Frameworks:** Create secure and ethical mechanisms for data sharing.
#     *   **Data Anonymization & Privacy:** Implement robust measures to protect individual privacy.
# 3.  **Capacity Building & Education:**
#     *   **Invest in STEM Education:** Strengthen foundational education in science, technology, engineering, and mathematics.
#     *   **AI Training Programs:** Develop specialized AI training programs for local talent.
#     *   **Digital Literacy Campaigns:** Educate the general population on how to use and understand digital tools.
#     *   **Foster Local Innovation:** Support local startups and research institutions in AI development.
# 4.  **Infrastructure Development:**
#     *   **Expand Internet Access:** Invest in affordable and reliable broadband infrastructure.
#     *   **Renewable Energy Solutions:** Develop sustainable energy sources to power AI systems.
#     *   **Edge AI:** Explore AI solutions that can run on less powerful devices with limited connectivity.
# 5.  **Ethical AI Frameworks:**
#     *   **Develop Local AI Ethics Guidelines:** Create guidelines that reflect local values and address specific societal concerns.
#     *   **Bias Mitigation:** Actively work to identify and reduce bias in data and algorithms.
#     *   **Transparency & Explainability:** Promote AI systems that are understandable and accountable.
# 6.  **Public-Private Partnerships:**
#     *   **Collaboration:** Foster partnerships between governments, NGOs, local businesses, international organizations, and academic institutions.
#     *   **Funding & Investment:** Attract investment for AI initiatives.
# 7.  **Open Source & Localized Solutions:**
#     *   **Leverage Open Source AI:** Utilize open-source tools and models to reduce development costs and foster local adaptation.
#     *   **Localization:** Ensure AI solutions are adapted to local languages, cultures, and contexts.
# 8.  **Pilot Projects & Scalability:**
#     *   **Start Small:** Implement pilot projects to test AI solutions in real-world settings.
#     *   **Design for Scalability:** Plan for how successful pilots can be expanded to reach a wider population.
#
# ## Examples of AI in Action (or Potential) in Developing Countries:
#
# *   **Zindi:** An African data science competition platform that connects data scientists with real-world problems from African organizations.
# *   **IBM's Project Lucy (Kenya):** Using AI to provide farmers with localized agricultural advice.
# *   **AI for Malaria Diagnosis (Rwanda/Uganda):** AI-powered microscopes to assist in faster and more accurate malaria diagnosis.
# *   **Credit Scoring in India/Africa:** Companies using alternative data for credit assessment for the unbanked.
# *   **Chatbots for Public Services (various countries):** Providing information on health, education, or government services in local languages.
#
# AI offers a transformative opportunity for developing countries to leapfrog traditional development challenges. However, success hinges on a thoughtful, ethical, and locally-driven approach that prioritizes human well-being, builds local capacity, and addresses the unique infrastructural and societal contexts of these regions.

# %%
from google import genai

client = genai.Client()
chat = client.chats.create(model="gemini-2.5-flash")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)

response = chat.send_message("How many paws are in my house?")
print(response.text)

for message in chat.get_history():
    print(f"role - {message.role}", end=": ")
    print(message.parts[0].text)
